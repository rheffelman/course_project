# %%
import os

folder = "./enemy_sprites/freya"

for filename in os.listdir(folder):
    if filename.endswith(".png") and not filename.startswith("freya_"):
        old_path = os.path.join(folder, filename)
        new_filename = "freya_" + filename
        new_path = os.path.join(folder, new_filename)
        os.rename(old_path, new_path)
        print(f"Renamed: {filename} -> {new_filename}")
# Out:
# Renamed: airdodge_strip6.png -> freya_airdodge_strip6.png
# Renamed: bair_hurt_strip8.png -> freya_bair_hurt_strip8.png
# Renamed: bair_strip8.png -> freya_bair_strip8.png
# Renamed: bighurt_strip1.png -> freya_bighurt_strip1.png
# Renamed: bouncehurt_strip1.png -> freya_bouncehurt_strip1.png
# Renamed: crouch_strip10.png -> freya_crouch_strip10.png
# Renamed: dair_hurt_strip8.png -> freya_dair_hurt_strip8.png
# Renamed: dair_strip8.png -> freya_dair_strip8.png
# Renamed: dashstart_strip4.png -> freya_dashstart_strip4.png
# Renamed: dashstop_strip2.png -> freya_dashstop_strip2.png
# Renamed: dashturn_strip5.png -> freya_dashturn_strip5.png
# Renamed: dash_strip8.png -> freya_dash_strip8.png
# Renamed: dattack_hurt_strip8.png -> freya_dattack_hurt_strip8.png
# Renamed: dattack_strip8.png -> freya_dattack_strip8.png
# Renamed: dive_boom_strip10.png -> freya_dive_boom_strip10.png
# Renamed: doublejump_strip4.png -> freya_doublejump_strip4.png
# Renamed: downhurt_strip1.png -> freya_downhurt_strip1.png
# Renamed: dspecial_hurt_strip10.png -> freya_dspecial_hurt_strip10.png
# Renamed: dspecial_strip10.png -> freya_dspecial_strip10.png
# Renamed: dstrong_hurt_strip14.png -> freya_dstrong_hurt_strip14.png
# Renamed: dstrong_strip14.png -> freya_dstrong_strip14.png
# Renamed: dtilt_hurt_strip6.png -> freya_dtilt_hurt_strip6.png
# Renamed: dtilt_strip6.png -> freya_dtilt_strip6.png
# Renamed: fair_hurt_strip10.png -> freya_fair_hurt_strip10.png
# Renamed: fair_strip10.png -> freya_fair_strip10.png
# Renamed: fspecial_hurt_strip16.png -> freya_fspecial_hurt_strip16.png
# Renamed: fspecial_strip16.png -> freya_fspecial_strip16.png
# Renamed: fstrong_hurt_strip8.png -> freya_fstrong_hurt_strip8.png
# Renamed: fstrong_strip8.png -> freya_fstrong_strip8.png
# Renamed: ftilt_hurt_strip7.png -> freya_ftilt_hurt_strip7.png
# Renamed: ftilt_strip7.png -> freya_ftilt_strip7.png
# Renamed: gauge_bg_strip1.png -> freya_gauge_bg_strip1.png
# Renamed: gauge_mask_strip1.png -> freya_gauge_mask_strip1.png
# Renamed: gauge_outline_strip2.png -> freya_gauge_outline_strip2.png
# Renamed: gauge_texture_strip1.png -> freya_gauge_texture_strip1.png
# Renamed: hurtground_strip1.png -> freya_hurtground_strip1.png
# Renamed: hurt_strip1.png -> freya_hurt_strip1.png
# Renamed: idle_strip6.png -> freya_idle_strip6.png
# Renamed: its_literally_nothing_strip1.png -> freya_its_literally_nothing_strip1.png
# Renamed: jab_hurt_strip5.png -> freya_jab_hurt_strip5.png
# Renamed: jab_strip5.png -> freya_jab_strip5.png
# Renamed: jumpstart_strip1.png -> freya_jumpstart_strip1.png
# Renamed: jump_strip5.png -> freya_jump_strip5.png
# Renamed: landinglag_strip2.png -> freya_landinglag_strip2.png
# Renamed: land_strip1.png -> freya_land_strip1.png
# Renamed: nair_hurt_strip10.png -> freya_nair_hurt_strip10.png
# Renamed: nair_strip10.png -> freya_nair_strip10.png
# Renamed: nspecial_hurt_strip8.png -> freya_nspecial_hurt_strip8.png
# Renamed: nspecial_strip8.png -> freya_nspecial_strip8.png
# Renamed: parry_strip6.png -> freya_parry_strip6.png
# Renamed: phone_open_strip7.png -> freya_phone_open_strip7.png
# Renamed: plat_strip10.png -> freya_plat_strip10.png
# Renamed: pratfall_strip1.png -> freya_pratfall_strip1.png
# Renamed: respawn_strip10.png -> freya_respawn_strip10.png
# Renamed: roll_backward_strip6.png -> freya_roll_backward_strip6.png
# Renamed: roll_forward_strip6.png -> freya_roll_forward_strip6.png
# Renamed: stardiver_boom_strip13.png -> freya_stardiver_boom_strip13.png
# Renamed: stardiver_ring_strip12.png -> freya_stardiver_ring_strip12.png
# Renamed: taunt_strip14.png -> freya_taunt_strip14.png
# Renamed: tech_strip5.png -> freya_tech_strip5.png
# Renamed: uair_hurt_strip8.png -> freya_uair_hurt_strip8.png
# Renamed: uair_strip8.png -> freya_uair_strip8.png
# Renamed: uphurt_strip1.png -> freya_uphurt_strip1.png
# Renamed: uspecial_hurt_strip11.png -> freya_uspecial_hurt_strip11.png
# Renamed: uspecial_strip11.png -> freya_uspecial_strip11.png
# Renamed: ustrong_hurt_strip12.png -> freya_ustrong_hurt_strip12.png
# Renamed: ustrong_strip12.png -> freya_ustrong_strip12.png
# Renamed: utilt_hurt_strip6.png -> freya_utilt_hurt_strip6.png
# Renamed: utilt_strip6.png -> freya_utilt_strip6.png
# Renamed: walkturn_strip3.png -> freya_walkturn_strip3.png
# Renamed: walk_strip12.png -> freya_walk_strip12.png
# Renamed: walljump_strip4.png -> freya_walljump_strip4.png
# Renamed: waveland_strip2.png -> freya_waveland_strip2.png
# Renamed: _pho_app_icons_strip7.png -> freya__pho_app_icons_strip7.png
# Renamed: _pho_base_strip1.png -> freya__pho_base_strip1.png
# Renamed: _pho_cooldown_arrow.png -> freya__pho_cooldown_arrow.png
# Renamed: _pho_example_bobble_body.png -> freya__pho_example_bobble_body.png
# Renamed: _pho_example_bobble_head.png -> freya__pho_example_bobble_head.png
# Renamed: _pho_example_speaker_strip4.png -> freya__pho_example_speaker_strip4.png
# Renamed: _pho_icon_strip1.png -> freya__pho_icon_strip1.png
# Renamed: _pho_offscreen_example.png -> freya__pho_offscreen_example.png
# Renamed: _pho_offscreen_strip8.png -> freya__pho_offscreen_strip8.png
